# %% [markdown]
# # Exploring our dataset.
#
# - starting by import the necessary tools

# %%
import pandas as pd
from pathlib import Path
import seaborn as sns

# %% [markdown]
# #### Loading the data files.
#
# - By using pathlib and resolve for importing several CSV fils

# %%
ROOT = Path ("lillmossi/Documents/github/Probability_model_for_football/data/csv_fils")

ROOT = Path("../..").resolve().parents[1]

files = list(ROOT.rglob("*.csv"))

df = pd.read_csv(files[0])
print("shape:", df.shape)
df.head()
# Out:
# shape: (97, 1)
#                                                                                                  ﻿Station;Startår för stationer som börjat efter 1901;Jan 2026;Normal 1991-20;Högsta sedan 1901;År;Lägsta sedan 1901;År;Medel max;Medel min;Högsta;Dag;Högsta sedan 1901;År;Lägsta;Dag;Lägsta sedan 1901;År;Frostdagar;Isdagar;Riktning;Hastighet
# Naimakka;1944;-21         5;-13 5;-5 5;1964;-22 0;1976;-16 0;-27 3;-2 4;25;6 5;1967;-38 3;9;-48                                9;1999;31;31;ESE ;8;
# Karesuando;;-22           4;-13 7;-5 1;1925;-22 2;1918;-17 2;-27 8;-0 8;18;7 2;1949;-40 1;11;-49                                 0;1999;31;31;E ;6;
# Katterjåkk;1904;-15       9;-10 3;-3 8;1964;-17 0;1968;-11 5;-20 0;2  0;18;7 6;1930;-28 0;8;-34                                  5;1958;31;30;S ;8;
# Kiruna flygplats;1901;-17 2;-11 3;-4 8;1964;-19 7;1994;-12 7;-22 5;-2 6;18;7 3;1949;-33 5;8;-43                                  3;1999;31;31;S ;9;
# ...

# %%
print("Missing values per colum:")
print(df.isna().sum())

print("\nDuplicate values per column:", df.duplicated().sum())
print("\nDuplicate values per row:", df.duplicated().sum())
print("\nDuplicate ")
# Out:
# Missing values per colum:
# ﻿Station;Startår för stationer som börjat efter 1901;Jan 2026;Normal 1991-20;Högsta sedan 1901;År;Lägsta sedan 1901;År;Medel max;Medel min;Högsta;Dag;Högsta sedan 1901;År;Lägsta;Dag;Lägsta sedan 1901;År;Frostdagar;Isdagar;Riktning;Hastighet    1
# dtype: int64
#
# Duplicate values per column: 0
#
# Duplicate values per row: 0
